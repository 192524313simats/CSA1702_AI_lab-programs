# %% [markdown]
# <a href="https://colab.research.google.com/github/192524313simats/CSA1702_AI_lab-programs/blob/main/EXP_NO_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from itertools import permutations

for p in permutations(range(10),8):
    d = dict(zip("SENDMORY",p))

    if d['S']==0 or d['M']==0:
        continue

    SEND = 1000*d['S']+100*d['E']+10*d['N']+d['D']
    MORE = 1000*d['M']+100*d['O']+10*d['R']+d['E']
    MONEY = 10000*d['M']+1000*d['O']+100*d['N']+10*d['E']+d['Y']

    if SEND+MORE == MONEY:
        print(d)
        print(SEND,"+",MORE,"=",MONEY)
        break
# Out:
# {'S': 9, 'E': 5, 'N': 6, 'D': 7, 'M': 1, 'O': 0, 'R': 8, 'Y': 2}
# 9567 + 1085 = 10652

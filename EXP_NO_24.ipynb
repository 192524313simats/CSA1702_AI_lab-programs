# %% [markdown]
# <a href="https://colab.research.google.com/github/192524313simats/CSA1702_AI_lab-programs/blob/main/EXP_NO_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.tree import DecisionTreeClassifier

X = [[1,60],[2,65],[3,70],[4,75],[5,80]]
y = ['Fail','Pass','Pass','Pass','Pass']

model = DecisionTreeClassifier()
model.fit(X,y)

a = int(input("Enter study hours: "))
b = int(input("Enter marks: "))

print("Prediction:", model.predict([[a,b]])[0])
# Out:
# Enter study hours: 3
# Enter marks: 70
# Prediction: Pass

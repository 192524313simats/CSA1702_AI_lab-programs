# %% [markdown]
# <a href="https://colab.research.google.com/github/192524313simats/CSA1702_AI_lab-programs/blob/main/EXP_NO_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import string

s = input("Enter string: ")

result = ""

for i in s:
    if i not in string.punctuation:
        result += i

print("Result:", result)
# Out:
# Enter string: HELLO, WORLD!
# Result: HELLO WORLD

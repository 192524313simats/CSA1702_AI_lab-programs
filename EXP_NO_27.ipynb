# %% [markdown]
# <a href="https://colab.research.google.com/github/192524313simats/CSA1702_AI_lab-programs/blob/main/EXP_NO_27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
people = {
    "Ravi": "10-05-2003",
    "Anu": "15-08-2004",
    "Kumar": "20-01-2002"
}

name = input("Enter name: ")

if name in people:
    print("DOB =", people[name])
else:
    print("Name not found")
# Out:
# Enter name: Ravi
# DOB = 10-05-2003

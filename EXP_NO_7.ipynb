# %% [markdown]
# <a href="https://colab.research.google.com/github/192524313simats/CSA1702_AI_lab-programs/blob/main/EXP_NO_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A = set(map(int, input("Enter Set A: ").split()))
B = set(map(int, input("Enter Set B: ").split()))

print("A-B =", A-B)
print("B-A =", B-A)
print("Symmetric Difference =", A^B)
# Out:
# Enter Set A: 1 2 3 4
# Enter Set B: 3 4 5 6
# A-B = {1, 2}
# B-A = {5, 6}
# Symmetric Difference = {1, 2, 5, 6}

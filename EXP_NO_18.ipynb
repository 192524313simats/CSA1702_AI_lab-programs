# %% [markdown]
# <a href="https://colab.research.google.com/github/192524313simats/CSA1702_AI_lab-programs/blob/main/EXP_NO_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from itertools import permutations

n = int(input("Number of cities: "))

cost = []

for i in range(n):
    cost.append(list(map(int,input().split())))

best = 999999
route = None

for p in permutations(range(1,n)):
    path = (0,)+p
    total = 0

    for i in range(n-1):
        total += cost[path[i]][path[i+1]]

    total += cost[path[-1]][0]

    if total < best:
        best = total
        route = path

print("Best route:",route)
print("Minimum cost:",best)
# Out:
# Number of cities: 4
# 0 10 15 20
# 10 0 35 25
# 15 35 0 30
# 20 25 30 0
# Best route: (0, 1, 3, 2)
# Minimum cost: 80

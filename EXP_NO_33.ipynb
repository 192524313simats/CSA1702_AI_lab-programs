# %% [markdown]
# <a href="https://colab.research.google.com/github/192524313simats/CSA1702_AI_lab-programs/blob/main/EXP_NO_33.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
disease = input("Enter disease: ").lower()

if disease == "fever":
    print("Avoid dating and take rest")
elif disease == "cold":
    print("Avoid dating and take rest")
elif disease == "cough":
    print("Dating can be considered")
else:
    print("Consult a doctor")
# Out:
# Enter disease: cough
# Dating can be considered
